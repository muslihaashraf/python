# %%
markslist=[80,76,85,93,67]
print(markslist[0])
# Out:
# 80

# %%
marks=[80,76,85,93,67]
marks.append(54)
print(marks)
# Out:
# [80, 76, 85, 93, 67, 54]

# %%
numberstuple=(10,20,52,63,85)
print(numberstuple)
# Out:
# (10, 20, 52, 63, 85)

# %%
s={52,85,52,64,21}
print(s)
# Out:
# {64, 85, 52, 21}

# %%
dict={"name":"shain","age":22,"mark":87}
print(dict["name"])
# Out:
# shain

# %%
name="jani"
print(name[0])
print(name[3])
# Out:
# j
# i
