# %%
a=int(input("enter a number :"))
if a==1:
  print("sunday")
elif(a==2):
  print("monday")
elif(a==3):
  print("tuesday")
elif(a==4):
   print("wednesday")
elif(a==5):
  print("thursday")
elif(a==6):
  print("friday")
elif(a==7):
   print("saturday")
else:
    print("enter number from 1-7")
# Out:
# enter a number :3
# tuesday

# %%
a=int(input("enter a number:"))
if(a%7==0):
    print("it is divisible by 7")
else:
    print("not divisible")
# Out:
# enter a number:28
# it is divisible by 7

# %%
a=(input("enter a character:"))
if(a in "a,e,i,o,u,A,E,I,O,U"):
    print("it is a vowel")
else:
    print("it is not a vowel")
# Out:
# enter a character:i
# it is a vowel

# %%
a=int(input("enter ur age:"))
if(a>=18):
    print("you are eligible to apply for a driving license")
else:
    print("you are not eligible to apply for a driving license")
# Out:
# enter ur age:17
# you are not eligible to apply for a driving license

# %%
a=(input("enter 1st string:"))
b=(input("enter 2nd string:"))
if(a==b):
    print("two strings are equal")
else:
    print("not equal")
# Out:
# enter 1st string:SAME
# enter 2nd string:SAME
# two strings are equal

# %%
a=int(input("enter purchase amount:"))
if(a>5000):
    print("customer is eligible for a discount")
else:
     print("customer is not eligible for a discount")
# Out:
# enter purchase amount:10000
# customer is eligible for a discount

# %%
a=int(input("enter a number:"))
if(a>=10 and a<=100):
    print("the number is lies between 10 & 100")
else:
    print("not in between 10 & 100")
# Out:
# enter a number:101
# not in between 10 & 100

# %%
a=int(input("enter ur attendance percentage:"))
if(a>=75):
    print("you are eligible to attend the exam")
else:
    print("you are not eligible to attend the exam")
# Out:
# enter ur attendance percentage:83
# you are eligible to attend the exam

# %%
a=input("enter an alpahbet:")
if a.isupper():
    print("it is uppercase")
else:
    print("it is lowercase")
# Out:
# enter an alpahbet:Y
# it is uppercase

# %%
a=int(input("enter a number"))
if(a>=100 and a<=999):
    print("it is 3 digit no.")
else:
    print("not a 3 digit")
# Out:
# enter a number776
# it is 3 digit no.

# %%
a=int(input("enter the amount of mobile data used in gb:"))
if(a<2):
    print("low usage")
elif(a>=2 and a<=5):
    print("moderate usage")
else:
    print("high usage")
# Out:
# enter the amount of mobile data used in gb:6
# high usage
