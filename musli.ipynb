# %%
name=input("enter name")
age=int(input("enter age"))
mark=float(input("enter mark"))
print("name= ",name)
print("age= ",age)
print("mark= ",mark )
# Out:
# enter namehg
# enter age65
# enter mark89.77
# name=  hg
# age=  65
# mark=  89.77
